# %% [markdown]
# <a href="https://colab.research.google.com/github/1234567890qqqqqq/-links-colab/blob/main/%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B8%AA%E0%B8%B4%E0%B8%97%E0%B8%98%E0%B8%B4%E0%B8%A0%E0%B8%B2%E0%B8%9E%E0%B8%A8%E0%B8%B9%E0%B8%99%E0%B8%A2%E0%B9%8C%E0%B8%9A%E0%B8%A3%E0%B8%B4%E0%B8%81%E0%B8%B2%E0%B8%A3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #นำไฟล์เข้า

# %%
import pandas as pd  # ใช้จัดการข้อมูลต่าง ๆ ที่เป็นตาราง พวกexcel ,CSV
from google.colab import drive # เชื่อม google drive กับ colab ของเรา นี้เป็นคำสั่งเชื่อม |accout colab กับ Drive ควรเป็น accout เดียวกัน|
drive.mount('/content/drive')
import os # การจัดเก็บเกี่ยวกับไฟล์ต่าง ๆ มันอยู่ที่โฟลเดอร์ไหน จะ list โฟล์เดอร์ออกมา
# Out:
# Mounted at /content/drive

# %%
# !pip install gspread matplotlib

# %%
# !pip install seaborn matplotlib

# %%
import warnings
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import pickle
import plotly.graph_objects as go
import plotly.express as px

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
# !ls
# Out:
# drive  sample_data  thsarabunnew-webfont.ttf

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %% [markdown]
# ###เทสภาษาไทย

# %%
import matplotlib.pyplot as plt
plt.text(0.1, 0.8,'สระ')
plt.text(0.1, 0.6,'วรรณยุกต์');

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
path = '/content/drive/MyDrive/TKN' #บอกทางผ่านในการไปเอาไฟล์ของเรา ว่าผ่านทางไหนบ้าง

# %%
df = pd.read_excel('/content/ประสิทธิภาพศูนย์บริการ.xlsx',sheet_name=0,skiprows=0, header=None)
df.head()
# Out:
#             0     1             2           3                4          5  \
# 0       เดือน   CPU  เป้าหมาย/CPU      รายได้  เป้าหมาย/รายได้  แบตเตอรี่
# 1      มกราคม  1345          1600  5856035.75          5780000         34
# 2  กุมภาพันธ์  1414          1600  6522438.42          5780000         64
# 3      มีนาคม  1437          1600  6758490.03          5780000         72
# 4      เมษายน   NaN           NaN         NaN              NaN        NaN
#
#                     6    7             8
# 0  เป้าหมาย/แบตเตอรี่  ยาง  เป้าหมาย/ยาง
# 1                  52  108           150
# 2                  52  123           150
# 3                  52  132           150
# 4                 NaN  NaN           NaN

# %%
vc = pd.read_excel('/content/ประสิทธิภาพศูนย์บริการ.xlsx',sheet_name='ประเมินรายบุคคล',skiprows=0)
vc.index = range(1, len(vc)+1)
vc
# Out:
#          เดือน   รายชื่อ  CPU  เป้าหมาย/CPU      รายได้  เป้าหมาย/รายได้  \
# 1       มกราคม     ยุทธ   154           200   975879.11           798000
# 2       มกราคม    นัฐพล   173           200   770641.54           798000
# 3       มกราคม  ดวงหทัย   151           200   620008.81           798000
# 4       มกราคม    กัลยา   183           200   723477.65           798000
# 5       มกราคม     โยธิน  154           200   657587.46           798000
# 6       มกราคม   กิตติพล  156           200   696672.32           798000
# 7       มกราคม     ณรงค์  201           200   841851.49           798000
# 8       มกราคม  น้ำทิพย์  173           200   569917.37           798000
# 9   กุมภาพันธ์     ยุทธ   195           200   940605.76           798000
# 10  กุมภาพันธ์    นัฐพล   170           200   975197.80           798000
# 11  กุมภาพันธ์  ดวงหทัย   189           200   731278.78           798000
# 12  กุมภาพันธ์    กัลยา   182           200   873899.75           798000
# 13  กุมภาพันธ์     โยธิน  152           200   794338.96           798000
# 14  กุมภาพันธ์   กิตติพล  134           200   617802.81           798000
# 15  กุมภาพันธ์     ณรงค์  182           200   851524.88           798000
# 16  กุมภาพันธ์  น้ำทิพย์  198           200   647726.69           798000
# 17      มีนาคม     ยุทธ   201           200  1213469.34           798000
# 18      มีนาคม    นัฐพล   177           200  1103518.49           798000
# 19      มีนาคม  ดวงหทัย   188           200   709121.67           798000
# 20      มีนาคม    กัลยา   197           200   856641.19           798000
# 21      มีนาคม     โยธิน  147           200   705725.25           798000
# 22      มีนาคม   กิตติพล  131           200   540552.03           798000
# 23      มีนาคม     ณรงค์  206           200   851524.88           798000
# 24      มีนาคม  น้ำทิพย์  190           200   777937.18           798000
#
#     แบตเตอรี่  เป้าหมาย/แบตเตอรี่  ยาง  เป้าหมาย/ยาง
# 1           8                   8   24            20
# 2           3                   8   36            20
# 3           2                   8    8            20
# 4           6                   8    8            20
# 5           0                   8    8            20
# 6           8                   8   12            20
# 7           4                   8   12            20
# 8           3                   8    0            20
# 9          15                   8   36            20
# 10          2                   8   32            20
# 11         10                   8   11            20
# 12         12                   8    8            20
# 13          5                   8    4            20
# 14          4                   8   20            20
# 15         10                   8    8            20
# 16          6                   8    4            20
# 17         17                   8   28            20
# 18          5                   8   32            20
# 19          5                   8    8            20
# 20         12                   8   16            20
# 21          9                   8   12            20
# 22          4                   8    0            20
# 23         14                   8   12            20
# 24          6                   8   24            20

# %% [markdown]
# #CPU

# %%
cpu = vc[['เดือน','รายชื่อ','CPU','เป้าหมาย/CPU']]
cpu
# Out:
#          เดือน   รายชื่อ  CPU  เป้าหมาย/CPU
# 1       มกราคม     ยุทธ   154           200
# 2       มกราคม    นัฐพล   173           200
# 3       มกราคม  ดวงหทัย   151           200
# 4       มกราคม    กัลยา   183           200
# 5       มกราคม     โยธิน  154           200
# 6       มกราคม   กิตติพล  156           200
# 7       มกราคม     ณรงค์  201           200
# 8       มกราคม  น้ำทิพย์  173           200
# 9   กุมภาพันธ์     ยุทธ   195           200
# 10  กุมภาพันธ์    นัฐพล   170           200
# 11  กุมภาพันธ์  ดวงหทัย   189           200
# 12  กุมภาพันธ์    กัลยา   182           200
# 13  กุมภาพันธ์     โยธิน  152           200
# 14  กุมภาพันธ์   กิตติพล  134           200
# 15  กุมภาพันธ์     ณรงค์  182           200
# 16  กุมภาพันธ์  น้ำทิพย์  198           200
# 17      มีนาคม     ยุทธ   201           200
# 18      มีนาคม    นัฐพล   177           200
# 19      มีนาคม  ดวงหทัย   188           200
# 20      มีนาคม    กัลยา   197           200
# 21      มีนาคม     โยธิน  147           200
# 22      มีนาคม   กิตติพล  131           200
# 23      มีนาคม     ณรงค์  206           200
# 24      มีนาคม  น้ำทิพย์  190           200

# %%
cpu['คิดเป็นเปอร์เซนต์'] = cpu['CPU']/200*100
cpu
# Out:
# <ipython-input-15-259ea757d03d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu['คิดเป็นเปอร์เซนต์'] = cpu['CPU']/200*100
#          เดือน   รายชื่อ  CPU  เป้าหมาย/CPU  คิดเป็นเปอร์เซนต์
# 1       มกราคม     ยุทธ   154           200               77.0
# 2       มกราคม    นัฐพล   173           200               86.5
# 3       มกราคม  ดวงหทัย   151           200               75.5
# 4       มกราคม    กัลยา   183           200               91.5
# 5       มกราคม     โยธิน  154           200               77.0
# 6       มกราคม   กิตติพล  156           200               78.0
# 7       มกราคม     ณรงค์  201           200              100.5
# 8       มกราคม  น้ำทิพย์  173           200               86.5
# 9   กุมภาพันธ์     ยุทธ   195           200               97.5
# 10  กุมภาพันธ์    นัฐพล   170           200               85.0
# 11  กุมภาพันธ์  ดวงหทัย   189           200               94.5
# 12  กุมภาพันธ์    กัลยา   182           200               91.0
# 13  กุมภาพันธ์     โยธิน  152           200               76.0
# 14  กุมภาพันธ์   กิตติพล  134           200               67.0
# 15  กุมภาพันธ์     ณรงค์  182           200               91.0
# 16  กุมภาพันธ์  น้ำทิพย์  198           200               99.0
# 17      มีนาคม     ยุทธ   201           200              100.5
# 18      มีนาคม    นัฐพล   177           200               88.5
# 19      มีนาคม  ดวงหทัย   188           200               94.0
# 20      มีนาคม    กัลยา   197           200               98.5
# 21      มีนาคม     โยธิน  147           200               73.5
# 22      มีนาคม   กิตติพล  131           200               65.5
# 23      มีนาคม     ณรงค์  206           200              103.0
# 24      มีนาคม  น้ำทิพย์  190           200               95.0

# %%
janc = cpu[cpu['เดือน']=='มกราคม'][['เดือน','รายชื่อ','CPU','เป้าหมาย/CPU']]
janc
# Out:
#     เดือน   รายชื่อ  CPU  เป้าหมาย/CPU
# 1  มกราคม     ยุทธ   154           200
# 2  มกราคม    นัฐพล   173           200
# 3  มกราคม  ดวงหทัย   151           200
# 4  มกราคม    กัลยา   183           200
# 5  มกราคม     โยธิน  154           200
# 6  มกราคม   กิตติพล  156           200
# 7  มกราคม     ณรงค์  201           200
# 8  มกราคม  น้ำทิพย์  173           200

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=[10,10]

# %%
# ข้อมูล
datac1 = janc['CPU']
labale = janc['รายชื่อ']
target = 200
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datac1,ec="#EBDD2B", fc="#FF9999")
plt.title('มกราคม')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datac1)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('CPU')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datac1):
    ax.text(i - 0.15, v + 1, str(v))

plt.show()

# %%
febc = cpu[cpu['เดือน']=='กุมภาพันธ์'][['เดือน','รายชื่อ','CPU','เป้าหมาย/CPU']]
febc
# Out:
#          เดือน   รายชื่อ  CPU  เป้าหมาย/CPU
# 9   กุมภาพันธ์     ยุทธ   195           200
# 10  กุมภาพันธ์    นัฐพล   170           200
# 11  กุมภาพันธ์  ดวงหทัย   189           200
# 12  กุมภาพันธ์    กัลยา   182           200
# 13  กุมภาพันธ์     โยธิน  152           200
# 14  กุมภาพันธ์   กิตติพล  134           200
# 15  กุมภาพันธ์     ณรงค์  182           200
# 16  กุมภาพันธ์  น้ำทิพย์  198           200

# %%
# ข้อมูล
datac2 = febc['CPU']
labale = febc['รายชื่อ']
target = 200
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datac2,ec="#EBDD2B", fc="#FF9999")
plt.title('กุมภาพันธ์')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datac2)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('CPU')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datac2):
    ax.text(i - 0.15, v + 1, str(v))

plt.show()

# %%
marc = cpu[cpu['เดือน']=='มีนาคม'][['เดือน','รายชื่อ','CPU','เป้าหมาย/CPU']]
marc
# Out:
#      เดือน   รายชื่อ  CPU  เป้าหมาย/CPU
# 17  มีนาคม     ยุทธ   201           200
# 18  มีนาคม    นัฐพล   177           200
# 19  มีนาคม  ดวงหทัย   188           200
# 20  มีนาคม    กัลยา   197           200
# 21  มีนาคม     โยธิน  147           200
# 22  มีนาคม   กิตติพล  131           200
# 23  มีนาคม     ณรงค์  206           200
# 24  มีนาคม  น้ำทิพย์  190           200

# %%
# ข้อมูล
datac3 = marc['CPU']
labale = marc['รายชื่อ']
target = 200
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datac3,ec="#EBDD2B", fc="#FF9999")
plt.title('มีนาคม')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datac3)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('CPU')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datac3):
    ax.text(i-0.1, v + 1, str(v))

plt.show()

# %% [markdown]
# #INCOME

# %%
income = vc[['เดือน','รายชื่อ','รายได้','เป้าหมาย/รายได้']]
income
# Out:
#          เดือน   รายชื่อ      รายได้  เป้าหมาย/รายได้
# 1       มกราคม     ยุทธ    975879.11           798000
# 2       มกราคม    นัฐพล    770641.54           798000
# 3       มกราคม  ดวงหทัย    620008.81           798000
# 4       มกราคม    กัลยา    723477.65           798000
# 5       มกราคม     โยธิน   657587.46           798000
# 6       มกราคม   กิตติพล   696672.32           798000
# 7       มกราคม     ณรงค์   841851.49           798000
# 8       มกราคม  น้ำทิพย์   569917.37           798000
# 9   กุมภาพันธ์     ยุทธ    940605.76           798000
# 10  กุมภาพันธ์    นัฐพล    975197.80           798000
# 11  กุมภาพันธ์  ดวงหทัย    731278.78           798000
# 12  กุมภาพันธ์    กัลยา    873899.75           798000
# 13  กุมภาพันธ์     โยธิน   794338.96           798000
# 14  กุมภาพันธ์   กิตติพล   617802.81           798000
# 15  กุมภาพันธ์     ณรงค์   851524.88           798000
# 16  กุมภาพันธ์  น้ำทิพย์   647726.69           798000
# 17      มีนาคม     ยุทธ   1213469.34           798000
# 18      มีนาคม    นัฐพล   1103518.49           798000
# 19      มีนาคม  ดวงหทัย    709121.67           798000
# 20      มีนาคม    กัลยา    856641.19           798000
# 21      มีนาคม     โยธิน   705725.25           798000
# 22      มีนาคม   กิตติพล   540552.03           798000
# 23      มีนาคม     ณรงค์   851524.88           798000
# 24      มีนาคม  น้ำทิพย์   777937.18           798000

# %%
jani = income[income['เดือน']=='มกราคม'][['เดือน','รายชื่อ','รายได้','เป้าหมาย/รายได้']]
jani
# Out:
#     เดือน   รายชื่อ     รายได้  เป้าหมาย/รายได้
# 1  มกราคม     ยุทธ   975879.11           798000
# 2  มกราคม    นัฐพล   770641.54           798000
# 3  มกราคม  ดวงหทัย   620008.81           798000
# 4  มกราคม    กัลยา   723477.65           798000
# 5  มกราคม     โยธิน  657587.46           798000
# 6  มกราคม   กิตติพล  696672.32           798000
# 7  มกราคม     ณรงค์  841851.49           798000
# 8  มกราคม  น้ำทิพย์  569917.37           798000

# %%
# ข้อมูล
datai1 = jani['รายได้']
labale = jani['รายชื่อ']
target = 798000
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datai1,ec="#EBDD2B", fc="#9370DB")
plt.title('มกราคม')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datai1)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('รายได้')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datai1):
    ax.text(i - 0.15, v + 1, str(v))

plt.show()

# %%
febi = income[income['เดือน']=='กุมภาพันธ์'][['เดือน','รายชื่อ','รายได้','เป้าหมาย/รายได้']]
febi
# Out:
#          เดือน   รายชื่อ     รายได้  เป้าหมาย/รายได้
# 9   กุมภาพันธ์     ยุทธ   940605.76           798000
# 10  กุมภาพันธ์    นัฐพล   975197.80           798000
# 11  กุมภาพันธ์  ดวงหทัย   731278.78           798000
# 12  กุมภาพันธ์    กัลยา   873899.75           798000
# 13  กุมภาพันธ์     โยธิน  794338.96           798000
# 14  กุมภาพันธ์   กิตติพล  617802.81           798000
# 15  กุมภาพันธ์     ณรงค์  851524.88           798000
# 16  กุมภาพันธ์  น้ำทิพย์  647726.69           798000

# %%
# ข้อมูล
datai2 = febi['รายได้']
labale = febi['รายชื่อ']
target = 798000
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datai2,ec="#EBDD2B", fc="#9370DB")
plt.title('กุมภาพันธ์')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datai2)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('รายได้')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datai2):
    ax.text(i - 0.15, v + 1, str(v))

plt.show()

# %%
mari = income[income['เดือน']=='มีนาคม'][['เดือน','รายชื่อ','รายได้','เป้าหมาย/รายได้']]
mari
# Out:
#      เดือน   รายชื่อ      รายได้  เป้าหมาย/รายได้
# 17  มีนาคม     ยุทธ   1213469.34           798000
# 18  มีนาคม    นัฐพล   1103518.49           798000
# 19  มีนาคม  ดวงหทัย    709121.67           798000
# 20  มีนาคม    กัลยา    856641.19           798000
# 21  มีนาคม     โยธิน   705725.25           798000
# 22  มีนาคม   กิตติพล   540552.03           798000
# 23  มีนาคม     ณรงค์   851524.88           798000
# 24  มีนาคม  น้ำทิพย์   777937.18           798000

# %%
# ข้อมูล
datai3 = mari['รายได้']
labale = mari['รายชื่อ']
target = 798000
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datai3,ec="#EBDD2B", fc="#9370DB")
plt.title('มีนาคม')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datai3)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('รายได้')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datai3):
    ax.text(i - 0.15, v + 1, str(v))

plt.show()

# %% [markdown]
# #batterys

# %%
batterys= vc[['เดือน','รายชื่อ','แบตเตอรี่','เป้าหมาย/แบตเตอรี่']]
batterys
# Out:
#          เดือน   รายชื่อ  แบตเตอรี่  เป้าหมาย/แบตเตอรี่
# 1       มกราคม     ยุทธ           8                   8
# 2       มกราคม    นัฐพล           3                   8
# 3       มกราคม  ดวงหทัย           2                   8
# 4       มกราคม    กัลยา           6                   8
# 5       มกราคม     โยธิน          0                   8
# 6       มกราคม   กิตติพล          8                   8
# 7       มกราคม     ณรงค์          4                   8
# 8       มกราคม  น้ำทิพย์          3                   8
# 9   กุมภาพันธ์     ยุทธ          15                   8
# 10  กุมภาพันธ์    นัฐพล           2                   8
# 11  กุมภาพันธ์  ดวงหทัย          10                   8
# 12  กุมภาพันธ์    กัลยา          12                   8
# 13  กุมภาพันธ์     โยธิน          5                   8
# 14  กุมภาพันธ์   กิตติพล          4                   8
# 15  กุมภาพันธ์     ณรงค์         10                   8
# 16  กุมภาพันธ์  น้ำทิพย์          6                   8
# 17      มีนาคม     ยุทธ          17                   8
# 18      มีนาคม    นัฐพล           5                   8
# 19      มีนาคม  ดวงหทัย           5                   8
# 20      มีนาคม    กัลยา          12                   8
# 21      มีนาคม     โยธิน          9                   8
# 22      มีนาคม   กิตติพล          4                   8
# 23      มีนาคม     ณรงค์         14                   8
# 24      มีนาคม  น้ำทิพย์          6                   8

# %%
janb = batterys[batterys['เดือน']=='มกราคม'][['เดือน','รายชื่อ','แบตเตอรี่','เป้าหมาย/แบตเตอรี่']]
janb
# Out:
#     เดือน   รายชื่อ  แบตเตอรี่  เป้าหมาย/แบตเตอรี่
# 1  มกราคม     ยุทธ           8                   8
# 2  มกราคม    นัฐพล           3                   8
# 3  มกราคม  ดวงหทัย           2                   8
# 4  มกราคม    กัลยา           6                   8
# 5  มกราคม     โยธิน          0                   8
# 6  มกราคม   กิตติพล          8                   8
# 7  มกราคม     ณรงค์          4                   8
# 8  มกราคม  น้ำทิพย์          3                   8

# %%
# ข้อมูล
datab1 = janb['แบตเตอรี่']
labale = janb['รายชื่อ']
target = 8
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datab1,ec="#EBDD2B", fc="#7fffd4")
plt.title('มกราคม')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datab1)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('แบตเตอรี่')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datab1):
    ax.text(i - 0.15, v + 0.05, str(v))

plt.show()

# %%
febb = batterys[batterys['เดือน']=='กุมภาพันธ์'][['เดือน','รายชื่อ','แบตเตอรี่','เป้าหมาย/แบตเตอรี่']]
febb
# Out:
#          เดือน   รายชื่อ  แบตเตอรี่  เป้าหมาย/แบตเตอรี่
# 9   กุมภาพันธ์     ยุทธ          15                   8
# 10  กุมภาพันธ์    นัฐพล           2                   8
# 11  กุมภาพันธ์  ดวงหทัย          10                   8
# 12  กุมภาพันธ์    กัลยา          12                   8
# 13  กุมภาพันธ์     โยธิน          5                   8
# 14  กุมภาพันธ์   กิตติพล          4                   8
# 15  กุมภาพันธ์     ณรงค์         10                   8
# 16  กุมภาพันธ์  น้ำทิพย์          6                   8

# %%
# ข้อมูล
datab2 = febb['แบตเตอรี่']
labale = febb['รายชื่อ']
target = 8
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datab2,ec="#EBDD2B", fc="#7fffd4")
plt.title('กุมภาพันธ์')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datab2)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('แบตเตอรี่')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datab2):
    ax.text(i - 0.15, v + 0.05, str(v))

plt.show()

# %%
marb = batterys[batterys['เดือน']=='มีนาคม'][['เดือน','รายชื่อ','แบตเตอรี่','เป้าหมาย/แบตเตอรี่']]
marb
# Out:
#      เดือน   รายชื่อ  แบตเตอรี่  เป้าหมาย/แบตเตอรี่
# 17  มีนาคม     ยุทธ          17                   8
# 18  มีนาคม    นัฐพล           5                   8
# 19  มีนาคม  ดวงหทัย           5                   8
# 20  มีนาคม    กัลยา          12                   8
# 21  มีนาคม     โยธิน          9                   8
# 22  มีนาคม   กิตติพล          4                   8
# 23  มีนาคม     ณรงค์         14                   8
# 24  มีนาคม  น้ำทิพย์          6                   8

# %%
# ข้อมูล
datab3 = marb['แบตเตอรี่']
labale = marb['รายชื่อ']
target = 8
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datab3,ec="#EBDD2B", fc="#7fffd4")
plt.title('มีนาคม')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datab3)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('แบตเตอรี่')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datab3):
    ax.text(i - 0.15, v + 0.05, str(v))

plt.show()

# %% [markdown]
# #tires

# %%
tires= vc[['เดือน','รายชื่อ','ยาง','เป้าหมาย/ยาง']]
tires
# Out:
#          เดือน   รายชื่อ  ยาง  เป้าหมาย/ยาง
# 1       มกราคม     ยุทธ    24            20
# 2       มกราคม    นัฐพล    36            20
# 3       มกราคม  ดวงหทัย     8            20
# 4       มกราคม    กัลยา     8            20
# 5       มกราคม     โยธิน    8            20
# 6       มกราคม   กิตติพล   12            20
# 7       มกราคม     ณรงค์   12            20
# 8       มกราคม  น้ำทิพย์    0            20
# 9   กุมภาพันธ์     ยุทธ    36            20
# 10  กุมภาพันธ์    นัฐพล    32            20
# 11  กุมภาพันธ์  ดวงหทัย    11            20
# 12  กุมภาพันธ์    กัลยา     8            20
# 13  กุมภาพันธ์     โยธิน    4            20
# 14  กุมภาพันธ์   กิตติพล   20            20
# 15  กุมภาพันธ์     ณรงค์    8            20
# 16  กุมภาพันธ์  น้ำทิพย์    4            20
# 17      มีนาคม     ยุทธ    28            20
# 18      มีนาคม    นัฐพล    32            20
# 19      มีนาคม  ดวงหทัย     8            20
# 20      มีนาคม    กัลยา    16            20
# 21      มีนาคม     โยธิน   12            20
# 22      มีนาคม   กิตติพล    0            20
# 23      มีนาคม     ณรงค์   12            20
# 24      มีนาคม  น้ำทิพย์   24            20

# %%
jant = tires[tires['เดือน']=='มกราคม'][['เดือน','รายชื่อ','ยาง','เป้าหมาย/ยาง']]
jant
# Out:
#     เดือน   รายชื่อ  ยาง  เป้าหมาย/ยาง
# 1  มกราคม     ยุทธ    24            20
# 2  มกราคม    นัฐพล    36            20
# 3  มกราคม  ดวงหทัย     8            20
# 4  มกราคม    กัลยา     8            20
# 5  มกราคม     โยธิน    8            20
# 6  มกราคม   กิตติพล   12            20
# 7  มกราคม     ณรงค์   12            20
# 8  มกราคม  น้ำทิพย์    0            20

# %%
# ข้อมูล
datat1 = jant['ยาง']
labale = jant['รายชื่อ']
target = 20
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datat1,ec="#EBDD2B", fc="#66CCFF")
plt.title('มกราคม')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datat1)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('ยาง')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datat1):
    ax.text(i - 0.15, v + 0.5, str(v))

plt.show()

# %%
febt = tires[tires['เดือน']=='กุมภาพันธ์'][['เดือน','รายชื่อ','ยาง','เป้าหมาย/ยาง']]
febt
# Out:
#          เดือน   รายชื่อ  ยาง  เป้าหมาย/ยาง
# 9   กุมภาพันธ์     ยุทธ    36            20
# 10  กุมภาพันธ์    นัฐพล    32            20
# 11  กุมภาพันธ์  ดวงหทัย    11            20
# 12  กุมภาพันธ์    กัลยา     8            20
# 13  กุมภาพันธ์     โยธิน    4            20
# 14  กุมภาพันธ์   กิตติพล   20            20
# 15  กุมภาพันธ์     ณรงค์    8            20
# 16  กุมภาพันธ์  น้ำทิพย์    4            20

# %%
# ข้อมูล
datat2 = febt['ยาง']
labale = febt['รายชื่อ']
target = 20
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datat2,ec="#EBDD2B", fc="#66CCFF")
plt.title('กุมภาพันธ์')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datat2)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('ยาง')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datat2):
    ax.text(i - 0.15, v + 0.5, str(v))

plt.show()

# %%
mart = tires[tires['เดือน']=='มีนาคม'][['เดือน','รายชื่อ','ยาง','เป้าหมาย/ยาง']]
mart
# Out:
#      เดือน   รายชื่อ  ยาง  เป้าหมาย/ยาง
# 17  มีนาคม     ยุทธ    28            20
# 18  มีนาคม    นัฐพล    32            20
# 19  มีนาคม  ดวงหทัย     8            20
# 20  มีนาคม    กัลยา    16            20
# 21  มีนาคม     โยธิน   12            20
# 22  มีนาคม   กิตติพล    0            20
# 23  มีนาคม     ณรงค์   12            20
# 24  มีนาคม  น้ำทิพย์   24            20

# %%
# ข้อมูล
datat3 = mart['ยาง']
labale = mart['รายชื่อ']
target = 20
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datat3,ec="#EBDD2B", fc="#66CCFF")
plt.title('มีนาคม')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datat3)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('ยาง')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datat3):
    ax.text(i - 0.15, v + 0.5, str(v))
#plt.text(7.5,-2, '-- เส้นเป้าหมาย/ยาง' , color='r' )
plt.show()

# %% [markdown]
# #EM60

# %%
em = pd.read_excel('/content/ประสิทธิภาพศูนย์บริการ.xlsx',sheet_name='EM60',skiprows=0)
em.index = range(1, len(em)+1)
em
# Out:
#     เดือน     ชื่อ SA  จำนวนลูกค้าเข้าเงื่อนไข EM Plus  \
# 1  มีนาคม     โยธิน                                 12
# 2  มีนาคม     กัลยา                                 36
# 3  มีนาคม   กิตติพล                                 15
# 4  มีนาคม      ณรงค์                                17
# 5  มีนาคม   ดวงหทัย                                 32
# 6  มีนาคม     นัฐพล                                 14
# 7  มีนาคม  น้ำทิพย์                                 27
# 8  มีนาคม       ยุทธ                                17
#
#    จำนวนลูกค้าที่สามารถส่งมอบได้ตรงเวลา  EM60 Achievement Rate
# 1                                     8               0.666667
# 2                                    36               1.000000
# 3                                    13               0.866667
# 4                                    14               0.823529
# 5                                    30               0.937500
# 6                                    12               0.857143
# 7                                    24               0.888889
# 8                                    17               1.000000

# %%
# ข้อมูลชุดที่ 1
dataem1 = em['จำนวนลูกค้าเข้าเงื่อนไข EM Plus']
# ข้อมูลชุดที่ 2
dataem2 = em['จำนวนลูกค้าที่สามารถส่งมอบได้ตรงเวลา']
#ใส่ชื่อSA
labels = em['ชื่อ SA']
# กำหนดตัวแปรเพื่อเก็บข้อมูลแกน x
x = np.arange(len(dataem1))

# กำหนดความกว้างของแท่ง
width = 0.35

# สร้างกราฟแท่ง
#fig, ax = plt.subplots()
#rects1 = ax.bar(x - width/2, dataem1, width, label='จำนวนลูกค้าเข้าเงื่อนไข EM Plus')
#rects2 = ax.bar(x + width/2, dataem2, width, label='จำนวนลูกค้าที่สามารถส่งมอบได้ตรงเวลา')
fig, ax = plt.subplots()
rects1 = ax.bar(labels, dataem1, width,fc="#FF69B4", label='จำนวนลูกค้าเข้าเงื่อนไข EM Plus')
rects2 = ax.bar(labels, dataem2, width, fc="#40E0D0", label='จำนวนลูกค้าที่สามารถส่งมอบได้ตรงเวลา')


# เพิ่มเนื้อหาต่างๆ ให้กับกราฟ
ax.set_ylabel('EM60')
ax.set_xlabel('รายชื่อ SA')
ax.set_title('รายงาน EM 60 ประจำเดือนมีนาคม 2566 ')
ax.set_xticks(x)
ax.legend()
# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(dataem1):
    ax.text(i - 0.075, v + 0.3, str(v))
for i, v in enumerate(dataem2):
    ax.text(i - 0.075, v + 0.3, str(v))
#แสดงชื่อใต้กราฟ
#for i, labels in enumerate(labels):
  #ax.text(i, -2 , labels, ha='center')
# แสดงกราฟ
plt.show()
