# %% [markdown]
# <a href="https://colab.research.google.com/github/1234567890qqqqqq/-links-colab/blob/main/%E0%B8%9B%E0%B8%A3%E0%B8%B0%E0%B8%AA%E0%B8%B4%E0%B8%97%E0%B8%98%E0%B8%B4%E0%B8%A0%E0%B8%B2%E0%B8%9E%E0%B8%A8%E0%B8%B9%E0%B8%99%E0%B8%A2%E0%B9%8C%E0%B8%9A%E0%B8%A3%E0%B8%B4%E0%B8%81%E0%B8%B2%E0%B8%A3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #นำไฟล์เข้า

# %%
import pandas as pd  # ใช้จัดการข้อมูลต่าง ๆ ที่เป็นตาราง พวกexcel ,CSV
from google.colab import drive # เชื่อม google drive กับ colab ของเรา นี้เป็นคำสั่งเชื่อม |accout colab กับ Drive ควรเป็น accout เดียวกัน|
drive.mount('/content/drive')
import os # การจัดเก็บเกี่ยวกับไฟล์ต่าง ๆ มันอยู่ที่โฟลเดอร์ไหน จะ list โฟล์เดอร์ออกมา
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install gspread matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install seaborn matplotlib
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import warnings
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from plotly.subplots import make_subplots
import pickle
import plotly.graph_objects as go
import plotly.express as px

# %%
# !wget -q https://github.com/Phonbopit/sarabun-webfont/raw/master/fonts/thsarabunnew-webfont.ttf

# %%
# !ls
# Out:
# drive			    thsarabunnew-webfont.ttf.2
# sample_data		    thsarabunnew-webfont.ttf.3
# thsarabunnew-webfont.ttf    thsarabunnew-webfont.ttf.4
# thsarabunnew-webfont.ttf.1  thsarabunnew-webfont.ttf.5

# %%
import matplotlib as mpl
mpl.font_manager.fontManager.addfont('thsarabunnew-webfont.ttf')
mpl.rc('font', family='TH Sarabun New')

# %% [markdown]
# ###เทสภาษาไทย

# %%
import matplotlib.pyplot as plt
plt.text(0.1, 0.8,'สระ')
plt.text(0.1, 0.6,'วรรณยุกต์');

# %%
path = '/content/drive/MyDrive/TKN' #บอกทางผ่านในการไปเอาไฟล์ของเรา ว่าผ่านทางไหนบ้าง

# %%
df = pd.read_excel('/content/drive/MyDrive/TKN/ประสิทธิภาพ - แก้.xlsx',sheet_name=0,skiprows=0, header=None)
df.head()
# Out:
#             0     1             2           3                4          5  \
# 0       เดือน   CPU  เป้าหมาย/CPU      รายได้  เป้าหมาย/รายได้  แบตเตอรี่
# 1      มกราคม  1345          1600  5856035.75          5780000         34
# 2  กุมภาพันธ์  1414          1600  6522438.42          5780000         64
# 3      มีนาคม  1437          1600  6758490.03          5780000         72
# 4      เมษายน   NaN           NaN         NaN              NaN        NaN
#
#                     6    7             8
# 0  เป้าหมาย/แบตเตอรี่  ยาง  เป้าหมาย/ยาง
# 1                  52  108           150
# 2                  52  123           150
# 3                  52  132           150
# 4                 NaN  NaN           NaN

# %%
vc = pd.read_excel('/content/drive/MyDrive/TKN/ประสิทธิภาพ - แก้.xlsx',sheet_name='ประเมินรายบุคคล',skiprows=0)
vc.index = range(1, len(vc)+1)
vc
# Out:
#          เดือน รายชื่อ  CPU  เป้าหมาย/CPU      รายได้  เป้าหมาย/รายได้  \
# 1       มกราคม     ยุท  154           200   975879.11           798000
# 2       มกราคม     นัฐ  173           200   770641.54           798000
# 3       มกราคม    หนิง  151           200   620008.81           798000
# 4       มกราคม    แอ๋ว  183           200   723477.65           798000
# 5       มกราคม      โย  154           200   657587.46           798000
# 6       มกราคม    เก๋ง  156           200   696672.32           798000
# 7       มกราคม   ณรงค์  201           200   841851.49           798000
# 8       มกราคม   ทิพย์  173           200   569917.37           798000
# 9   กุมภาพันธ์     ยุท  195           200   940605.76           798000
# 10  กุมภาพันธ์     นัฐ  170           200   975197.80           798000
# 11  กุมภาพันธ์    หนิง  189           200   731278.78           798000
# 12  กุมภาพันธ์    แอ๋ว  182           200   873899.75           798000
# ...

# %% [markdown]
# #CPU

# %%
cpu = vc[['เดือน','รายชื่อ','CPU','เป้าหมาย/CPU']]
cpu
# Out:
#          เดือน รายชื่อ  CPU  เป้าหมาย/CPU
# 1       มกราคม     ยุท  154           200
# 2       มกราคม     นัฐ  173           200
# 3       มกราคม    หนิง  151           200
# 4       มกราคม    แอ๋ว  183           200
# 5       มกราคม      โย  154           200
# 6       มกราคม    เก๋ง  156           200
# 7       มกราคม   ณรงค์  201           200
# 8       มกราคม   ทิพย์  173           200
# 9   กุมภาพันธ์     ยุท  195           200
# 10  กุมภาพันธ์     นัฐ  170           200
# 11  กุมภาพันธ์    หนิง  189           200
# 12  กุมภาพันธ์    แอ๋ว  182           200
# 13  กุมภาพันธ์      โย  152           200
# 14  กุมภาพันธ์    เก๋ง  134           200
# 15  กุมภาพันธ์   ณรงค์  182           200
# 16  กุมภาพันธ์   ทิพย์  198           200
# 17      มีนาคม     ยุท  201           200
# 18      มีนาคม     นัฐ  177           200
# 19      มีนาคม    หนิง  188           200
# 20      มีนาคม    แอ๋ว  197           200
# 21      มีนาคม      โย  147           200
# ...

# %%
cpu['คิดเป็นเปอร์เซนต์'] = cpu['CPU']/200*100
cpu
# Out:
# <ipython-input-259-259ea757d03d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cpu['คิดเป็นเปอร์เซนต์'] = cpu['CPU']/200*100
#          เดือน รายชื่อ  CPU  เป้าหมาย/CPU  คิดเป็นเปอร์เซนต์
# 1       มกราคม     ยุท  154           200               77.0
# 2       มกราคม     นัฐ  173           200               86.5
# 3       มกราคม    หนิง  151           200               75.5
# 4       มกราคม    แอ๋ว  183           200               91.5
# 5       มกราคม      โย  154           200               77.0
# 6       มกราคม    เก๋ง  156           200               78.0
# 7       มกราคม   ณรงค์  201           200              100.5
# 8       มกราคม   ทิพย์  173           200               86.5
# ...

# %%
janc = cpu[cpu['เดือน']=='มกราคม'][['เดือน','รายชื่อ','CPU','เป้าหมาย/CPU']]
janc
# Out:
#     เดือน รายชื่อ  CPU  เป้าหมาย/CPU
# 1  มกราคม     ยุท  154           200
# 2  มกราคม     นัฐ  173           200
# 3  มกราคม    หนิง  151           200
# 4  มกราคม    แอ๋ว  183           200
# 5  มกราคม      โย  154           200
# 6  มกราคม    เก๋ง  156           200
# 7  มกราคม   ณรงค์  201           200
# 8  มกราคม   ทิพย์  173           200

# %%
import matplotlib
matplotlib.rcParams['figure.figsize']=[10,10]

# %%
# ข้อมูล
datac1 = janc['CPU']
labale = janc['รายชื่อ']
target = 200
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datac1,ec="#EBDD2B", fc="#7fffd4")
plt.title('มกราคม')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datac1)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('CPU')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datac1):
    ax.text(i - 0.15, v + 1, str(v))

plt.show()

# %%
febc = cpu[cpu['เดือน']=='กุมภาพันธ์'][['เดือน','รายชื่อ','CPU','เป้าหมาย/CPU']]
febc
# Out:
#          เดือน รายชื่อ  CPU  เป้าหมาย/CPU
# 9   กุมภาพันธ์     ยุท  195           200
# 10  กุมภาพันธ์     นัฐ  170           200
# 11  กุมภาพันธ์    หนิง  189           200
# 12  กุมภาพันธ์    แอ๋ว  182           200
# 13  กุมภาพันธ์      โย  152           200
# 14  กุมภาพันธ์    เก๋ง  134           200
# 15  กุมภาพันธ์   ณรงค์  182           200
# 16  กุมภาพันธ์   ทิพย์  198           200

# %%
# ข้อมูล
datac2 = febc['CPU']
labale = febc['รายชื่อ']
target = 200
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datac2,ec="#EBDD2B", fc="#7fffd4")
plt.title('กุมภาพันธ์')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datac2)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('CPU')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datac2):
    ax.text(i - 0.15, v + 1, str(v))

plt.show()

# %%
marc = cpu[cpu['เดือน']=='มีนาคม'][['เดือน','รายชื่อ','CPU','เป้าหมาย/CPU']]
marc
# Out:
#      เดือน รายชื่อ  CPU  เป้าหมาย/CPU
# 17  มีนาคม     ยุท  201           200
# 18  มีนาคม     นัฐ  177           200
# 19  มีนาคม    หนิง  188           200
# 20  มีนาคม    แอ๋ว  197           200
# 21  มีนาคม      โย  147           200
# 22  มีนาคม    เก๋ง  131           200
# 23  มีนาคม   ณรงค์  206           200
# 24  มีนาคม   ทิพย์  190           200

# %%
# ข้อมูล
datac3 = marc['CPU']
labale = marc['รายชื่อ']
target = 200
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datac3,ec="#EBDD2B", fc="#7fffd4")
plt.title('มีนาคม')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datac3)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('CPU')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datac3):
    ax.text(i-0.1, v + 1, str(v))

plt.show()

# %% [markdown]
# #INCOME

# %%
income = vc[['เดือน','รายชื่อ','รายได้','เป้าหมาย/รายได้']]
income
# Out:
#          เดือน รายชื่อ      รายได้  เป้าหมาย/รายได้
# 1       มกราคม     ยุท   975879.11           798000
# 2       มกราคม     นัฐ   770641.54           798000
# 3       มกราคม    หนิง   620008.81           798000
# 4       มกราคม    แอ๋ว   723477.65           798000
# 5       มกราคม      โย   657587.46           798000
# 6       มกราคม    เก๋ง   696672.32           798000
# 7       มกราคม   ณรงค์   841851.49           798000
# 8       มกราคม   ทิพย์   569917.37           798000
# 9   กุมภาพันธ์     ยุท   940605.76           798000
# 10  กุมภาพันธ์     นัฐ   975197.80           798000
# 11  กุมภาพันธ์    หนิง   731278.78           798000
# 12  กุมภาพันธ์    แอ๋ว   873899.75           798000
# 13  กุมภาพันธ์      โย   794338.96           798000
# 14  กุมภาพันธ์    เก๋ง   617802.81           798000
# 15  กุมภาพันธ์   ณรงค์   851524.88           798000
# 16  กุมภาพันธ์   ทิพย์   647726.69           798000
# 17      มีนาคม     ยุท  1213469.34           798000
# ...

# %%
jani = income[income['เดือน']=='มกราคม'][['เดือน','รายชื่อ','รายได้','เป้าหมาย/รายได้']]
jani
# Out:
#     เดือน รายชื่อ     รายได้  เป้าหมาย/รายได้
# 1  มกราคม     ยุท  975879.11           798000
# 2  มกราคม     นัฐ  770641.54           798000
# 3  มกราคม    หนิง  620008.81           798000
# 4  มกราคม    แอ๋ว  723477.65           798000
# 5  มกราคม      โย  657587.46           798000
# 6  มกราคม    เก๋ง  696672.32           798000
# 7  มกราคม   ณรงค์  841851.49           798000
# 8  มกราคม   ทิพย์  569917.37           798000

# %%
# ข้อมูล
datai1 = jani['รายได้']
labale = jani['รายชื่อ']
target = 798000
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datai1,ec="#EBDD2B", fc="#7fffd4")
plt.title('มกราคม')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datai1)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('รายได้')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datai1):
    ax.text(i - 0.15, v + 1, str(v))

plt.show()

# %%
febi = income[income['เดือน']=='กุมภาพันธ์'][['เดือน','รายชื่อ','รายได้','เป้าหมาย/รายได้']]
febi
# Out:
#          เดือน รายชื่อ     รายได้  เป้าหมาย/รายได้
# 9   กุมภาพันธ์     ยุท  940605.76           798000
# 10  กุมภาพันธ์     นัฐ  975197.80           798000
# 11  กุมภาพันธ์    หนิง  731278.78           798000
# 12  กุมภาพันธ์    แอ๋ว  873899.75           798000
# 13  กุมภาพันธ์      โย  794338.96           798000
# 14  กุมภาพันธ์    เก๋ง  617802.81           798000
# 15  กุมภาพันธ์   ณรงค์  851524.88           798000
# 16  กุมภาพันธ์   ทิพย์  647726.69           798000

# %%
# ข้อมูล
datai2 = febi['รายได้']
labale = febi['รายชื่อ']
target = 798000
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datai2,ec="#EBDD2B", fc="#7fffd4")
plt.title('กุมภาพันธ์')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datai2)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('รายได้')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datai2):
    ax.text(i - 0.15, v + 1, str(v))

plt.show()

# %%
mari = income[income['เดือน']=='มีนาคม'][['เดือน','รายชื่อ','รายได้','เป้าหมาย/รายได้']]
mari
# Out:
#      เดือน รายชื่อ      รายได้  เป้าหมาย/รายได้
# 17  มีนาคม     ยุท  1213469.34           798000
# 18  มีนาคม     นัฐ  1103518.49           798000
# 19  มีนาคม    หนิง   709121.67           798000
# 20  มีนาคม    แอ๋ว   856641.19           798000
# 21  มีนาคม      โย   705725.25           798000
# 22  มีนาคม    เก๋ง   540552.03           798000
# 23  มีนาคม   ณรงค์   851524.88           798000
# 24  มีนาคม   ทิพย์   777937.18           798000

# %%
# ข้อมูล
datai3 = mari['รายได้']
labale = mari['รายชื่อ']
target = 798000
fig, ax = plt.subplots()

# สร้างแท่งกราฟ
plt.bar(labale,datai3,ec="#EBDD2B", fc="#7fffd4")
plt.title('มีนาคม')

# กำหนดเส้นเป้าหมายด้วยวงกลมและเส้นต่อเนื่อง
ax.axhline(y=target, color='r', linestyle='--')
ax.plot([0, len(datai3)], [target, target], 'r--')

# กำหนดชื่อแกน
ax.set_xlabel('รายชื่อ')
ax.set_ylabel('รายได้')

# แสดงเลขบนแท่งกราฟ
for i, v in enumerate(datai3):
    ax.text(i - 0.15, v + 1, str(v))

plt.show()

# %% [markdown]
# #batterys

# %% [markdown]
# #tires
